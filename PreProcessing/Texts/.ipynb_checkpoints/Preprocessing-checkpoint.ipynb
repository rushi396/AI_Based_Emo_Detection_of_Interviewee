# %%
import numpy
import pandas
import matplotlib.pyplot as pyplot
import seaborn

import nltk
from nltk.corpus import stopwords,wordnet
from nltk.stem import WordNetLemmatizer

import re

# %%
# %matplotlib qt
# %matplotlib inline
pyplot.rcParams["figure.figsize"] = (15, 12)

# %%
classes_list=["sadness","joy","love","anger","fear","surprise"]

# %%
filename="Emotions_Dataset.csv"

# %%
data=pandas.read_csv('../../Data/Main_Data/Text_Data/'+filename)

# %%
class_column='label'
review_column='text'

# %%
data
# Out:
#                                                     text  label
# 0                                i didnt feel humiliated      0
# 1      i can go from feeling so hopeless to so damned...      0
# 2       im grabbing a minute to post i feel greedy wrong      3
# 3      i am ever feeling nostalgic about the fireplac...      2
# 4                                   i am feeling grouchy      3
# ...                                                  ...    ...
# 19995  im having ssa examination tomorrow in the morn...      0
# 19996  i constantly worry about their fight against n...      1
# 19997  i feel its important to share this info for th...      1
# 19998  i truly feel that if you are passionate enough...      1
# 19999  i feel like i just wanna buy any cute make up ...      1
#
# [20000 rows x 2 columns]

# %%
data.describe()
# Out:
#               label
# count  20000.000000
# mean       1.562850
# std        1.496684
# min        0.000000
# 25%        0.000000
# 50%        1.000000
# 75%        3.000000
# max        5.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text    20000 non-null  object
#  1   label   20000 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 312.6+ KB

# %%
data[class_column].value_counts()
# Out:
# 1    6761
# 0    5797
# 3    2709
# 4    2373
# 2    1641
# 5     719
# Name: label, dtype: int64

# %%
list(data[class_column].unique())
# Out:
# [0, 3, 2, 5, 4, 1]

# %%
pyplot.pie(data[class_column].value_counts(),labels=classes_list)
# Out:
# ([<matplotlib.patches.Wedge at 0x1c4d777b7c0>,
# ...
#  [Text(0.5358242191644744, 0.9606728923815752, 'sadness'),
#   Text(-1.0937124393622855, 0.11744402915516555, 'joy'),
#   Text(-0.36854448991788274, -1.0364241211739371, 'love'),
#   Text(0.485019021914126, -0.9872975986912279, 'anger'),
#   Text(0.9738348294354211, -0.511513171852382, 'fear'),
#   Text(1.0929919364588851, -0.1239702659344418, 'surprise')])

# %%
pyplot.scatter(data[class_column].to_numpy(),data[class_column].to_numpy())

# %%
pyplot.plot(data[class_column].to_numpy()[:500],linestyle = 'solid')

# %%
data[review_column][0]
# Out:
# 'i didnt feel humiliated'

# %%
pyplot.hist([len(text.split()) for text in data[review_column][:500]])
# Out:
# (array([ 85., 113., 115.,  70.,  55.,  21.,  25.,  10.,   4.,   2.]),
#  array([ 3. ,  9.1, 15.2, 21.3, 27.4, 33.5, 39.6, 45.7, 51.8, 57.9, 64. ]),
#  <BarContainer object of 10 artists>)

# %%
pyplot.plot([len(text.split()) for text in data[review_column][:50]])

# %% [markdown]
# # Morphological Analysis 👇

# %%
word_lemitizer=WordNetLemmatizer()

# %%
Regular_expression_definition_for_html_tags=re.compile('<.*?>')
Regular_expression_definition_for_digits=re.compile('\d+\s|\s\d+|\s\d+\s')
Regular_expression_definition_for_links=re.compile('http://\S+|https://\S+')

# %%
Regular_expression_definition_for_digits
# Out:
# re.compile(r'\d+\s|\s\d+|\s\d+\s', re.UNICODE)

# %%
Regular_expression_definition_for_html_tags
# Out:
# re.compile(r'<.*?>', re.UNICODE)

# %%
Regular_expression_definition_for_links
# Out:
# re.compile(r'http://\S+|https://\S+', re.UNICODE)

# %%
Regular_expression_definition_for_html_tags.sub(r" ","<     h1> This is a h1 tag </h1>").strip()
# Out:
# 'This is a h1 tag'

# %%
english_stop_words=stopwords.words('english')

# %%
english_stop_words
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
# ...

# %%
english_stop_words.index("the")
# Out:
# 62

# %% [markdown]
# ## This is used to compare the words before and after the lemmitization

# %%
def lemmetize_comparer(text):
    text=text.lower().split()
    text=[word for word in text if word not in english_stop_words]
    text_=[word_lemitizer.lemmatize(word) for word in text]
    for i in range(len(text_)):
        print(text[i]," ->",text_[i])

# %%
lemmetize_comparer(data[review_column][100])
# Out:
# wont  -> wont
# let  -> let
# child  -> child
# cry  -> cry
# feel  -> feel
# loving  -> loving
# lily  -> lily
# little  -> little
# going  -> going
# opportunities  -> opportunity
# lasted  -> lasted
# short  -> short
# months  -> month

# %% [markdown]
# ## This Function will preprocess thegiven sentence
# process on each word
#
# converts in to lower case
#
# romoves stop words
#
# uses lemmitizer on each word

# %%
syns = wordnet.synsets("video")

# %%
syns
# Out:
# [Synset('video.n.01'),
#  Synset('video_recording.n.01'),
#  Synset('video.n.03'),
#  Synset('television.n.01')]

# %%
def preprocessing_of_sentence(text):
    word_to_be_handled=[
    "not",
    "no",
    "very"
    ]
    text = re.sub(r"http\S+|www\S+|https\S+", '', text, flags=re.MULTILINE)
    text=Regular_expression_definition_for_html_tags.sub(r" ",text)
    text=Regular_expression_definition_for_digits.sub(r" ",text)
    text=Regular_expression_definition_for_links.sub(r" ",text)
    punctuations = [".","=","_","<",">",",","!","?","'",'"',":",";","*","-","/","+","%","$","#","@","(",")","[","]","{","}",'\n']
    for i in punctuations:
        text = text.replace(i," ")
    text=text.lower().split()
    text=[word for word in text if word not in english_stop_words and len(word)>1 or word in word_to_be_handled]
    text=[word_lemitizer.lemmatize(word) for word in text]
    return text

# %%
preprocessing_of_sentence(data[review_column][100])
# Out:
# ['wont',
#  'let',
#  'child',
#  'cry',
#  'feel',
#  'loving',
#  'lily',
#  'little',
#  'going',
#  'opportunity',
#  'lasted',
#  'short',
#  'month']

# %%
len(preprocessing_of_sentence(data[review_column][100]))
# Out:
# 13

# %%
Preprocessed_textual_data=[" ".join(preprocessing_of_sentence(text)) for text in data[review_column]]

# %%
Preprocessed_textual_data
# Out:
# ['didnt feel humiliated',
#  'go feeling hopeless damned hopeful around someone care awake',
#  'im grabbing minute post feel greedy wrong',
#  'ever feeling nostalgic fireplace know still property',
#  'feeling grouchy',
#  'ive feeling little burdened lately wasnt sure',
#  'ive taking milligram time recommended amount ive fallen asleep lot faster also feel like funny',
#  'feel confused life teenager jaded year old man',
#  'petronas year feel petronas performed well made huge profit',
#  'feel romantic',
#  'feel like make suffering seeing mean something',
#  'feel running divine experience expect type spiritual encounter',
#  'think easiest time year feel dissatisfied',
#  'feel low energy thirsty',
#  'immense sympathy general point possible proto writer trying find time write corner life no sign agent let alone publishing contract feel little precious',
#  'not feel reassured anxiety side',
#  'didnt really feel embarrassed',
#  'feel pretty pathetic time',
# ...

# %%
Preprocessed_Data=data

# %%
Preprocessed_Data[review_column]=Preprocessed_textual_data

# %%
Preprocessed_Data
# Out:
#                                                     text  label
# 0                                  didnt feel humiliated      0
# 1      go feeling hopeless damned hopeful around some...      0
# 2              im grabbing minute post feel greedy wrong      3
# 3      ever feeling nostalgic fireplace know still pr...      2
# 4                                        feeling grouchy      3
# ...                                                  ...    ...
# 19995  im ssa examination tomorrow morning im quite w...      0
# 19996  constantly worry fight nature push limit inner...      1
# 19997         feel important share info experience thing      1
# 19998  truly feel passionate enough something stay tr...      1
# 19999  feel like wanna buy cute make see online even one      1
#
# [20000 rows x 2 columns]

# %% [markdown]
# # Saving the processed data

# %%
Preprocessed_Data.to_csv('../../Data/Preprocessed_Data/Processed_'+filename,index=False)
